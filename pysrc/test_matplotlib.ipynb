# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,0,9],[1,6,9])

# %%
print('null')
# Out:
# null

# %%
import random
x = range(0,100,5) # x-axis position
y = [random.randint(0,100) for i in x]
plt.figure(figsize=(20,8),dpi=80)
plt.plot(x,y)
plt.show()
